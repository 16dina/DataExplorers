# %%
# %pip install pycaret
# %pip install --upgrade scipy

# %%
# %pip install -U yellowbrick

# %%
# !pip uninstall yellowbrick
# !pip install yellowbrick

# %% [markdown]
# # Pycaret on Crops dataset
#
# In this notebook we use pycaret to find the best model for predicting the production for the countries in the dataset. We tried different iterations for getting the best features to predict and also the best model.

# %% [markdown]
# # 1 Importing crops dataset and needed packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from pycaret.regression import *

# %%
sheet_stats = ['CropStats']
df = pd.concat(pd.read_excel('/content/drive/MyDrive/Colab Notebooks/CloudAI/crops.xlsx', sheet_name=sheet_stats))
df
# Out:
#                  Unnamed: 0  Harvest_year   admin0    admin1   crop  \
# CropStats 0               0          1902  Austria       NaN  wheat
#           1               1          1903  Austria       NaN  wheat
#           2               2          1904  Austria       NaN  wheat
#           3               3          1905  Austria       NaN  wheat
#           4               4          1906  Austria       NaN  wheat
# ...                     ...           ...      ...       ...    ...
#           36702       36702          2013    China  zhejiang  wheat
#           36703       36703          2014    China  zhejiang  wheat
#           36704       36704          2015    China  zhejiang  wheat
#           36705       36705          2016    China  zhejiang  wheat
#           36706       36706          2017    China  zhejiang  wheat
#
#                  hectares (ha)  production (tonnes)  year  yield(tonnes/ha)  \
# CropStats 0                NaN                  NaN  1902          1.310000
#           1                NaN                  NaN  1903          1.470000
#           2                NaN                  NaN  1904          1.270000
#           3                NaN                  NaN  1905          1.330000
#           4                NaN                  NaN  1906          1.280000
# ...                        ...                  ...   ...               ...
#           36702        75520.0             278300.0  2013          3.685117
#           36703        82120.0             309500.0  2014          3.768875
#           36704        89800.0             351300.0  2015          3.912027
#           36705        76590.0             253900.0  2016          3.315054
#           36706       103670.0             419200.0  2017          4.043600
#
#                  admin2 notes
# CropStats 0         NaN   NaN
#           1         NaN   NaN
#           2         NaN   NaN
#           3         NaN   NaN
#           4         NaN   NaN
# ...                 ...   ...
#           36702     NaN   NaN
#           36703     NaN   NaN
#           36704     NaN   NaN
#           36705     NaN   NaN
#           36706     NaN   NaN
#
# [36707 rows x 11 columns]

# %% [markdown]
# # 2 Preprocessing of the data for training our model

# %%
# Removing the notes column because it is of no use for our model.
notes_values = df['notes'].dropna().tolist()
# Drop the columns notes and admin2 (not useful)
df = df.drop(columns=['notes', 'admin2'])
# Rename 'admin0' to 'Country' and 'admin1' to 'City'
df = df.rename(columns={'admin0': 'Country', 'admin1': 'City'})
df["City"].fillna("Not defined", inplace=True)
# Fill the null values of hectares, production and yield with 0 to not miss any upon calculation
df.fillna(0, inplace=True)
df = df[~((df['production (tonnes)'] == 0) & ((df['yield(tonnes/ha)'] == 0) | (df['hectares (ha)'] == 0)))]
# Find the indexes of rows where 'production' is zero
zero_indexes = df[df['production (tonnes)'] == 0].index
# Loop through the zero valued indexes and calculate the missing 'production' values
for index in zero_indexes:
    df.at[index, 'production (tonnes)'] = df.at[index, 'yield(tonnes/ha)'] * df.at[index, 'hectares (ha)']
# Some might argue that we should keep the row if the production has a value but yield doesn't, but in our case we need rows without zeros for a good prediction
df = df[~((df['yield(tonnes/ha)'] == 0) & ((df['production (tonnes)'] == 0) | (df['hectares (ha)'] == 0)))]
# Some might argue that we should keep the row if the production has a value but hectares doesn't, but in our case we need rows without zeros for a good prediction
df = df[~((df['hectares (ha)'] == 0) & ((df['production (tonnes)'] == 0) | (df['yield(tonnes/ha)'] == 0)))]
# Find the indexes of rows where 'hectares' is zero
zero_indexes = df[df['hectares (ha)'] == 0].index
# Loop through the zero valued indexes and calculate the missing 'hectares' values
for index in zero_indexes:
    df.at[index, 'hectares (ha)'] = df.at[index, 'production (tonnes)'] / df.at[index, 'yield(tonnes/ha)']
# Count the number of rows with 0 in "hectares (ha)" to verify
count_zero_hectares = len(df[df['hectares (ha)'] == 0])
# Select specific columns and reorder them
df = df[['year', 'Harvest_year', 'crop', 'hectares (ha)', 'yield(tonnes/ha)', 'production (tonnes)']]
df = pd.get_dummies(df, columns=['crop'])
cols_to_drop = ['Harvest_year']
df.drop(columns=cols_to_drop, axis=1, inplace=True)
df
# Out:
#                  year  hectares (ha)  yield(tonnes/ha)  production (tonnes)  \
# CropStats 59     1961       275822.0          2.580000           711620.760
#           60     1962       270351.0          2.612000           706156.812
#           61     1963       274722.0          2.510000           689552.220
#           62     1964       282967.0          2.652000           750428.484
#           63     1965       275654.0          2.397000           660742.638
# ...               ...            ...               ...                  ...
#           36702  2013        75520.0          3.685117           278300.000
#           36703  2014        82120.0          3.768875           309500.000
#           36704  2015        89800.0          3.912027           351300.000
#           36705  2016        76590.0          3.315054           253900.000
#           36706  2017       103670.0          4.043600           419200.000
#
#                  crop_cereals  crop_maize  crop_spring wheat  crop_wheat  \
# CropStats 59                0           0                  0           1
#           60                0           0                  0           1
#           61                0           0                  0           1
#           62                0           0                  0           1
#           63                0           0                  0           1
# ...                       ...         ...                ...         ...
#           36702             0           0                  0           1
#           36703             0           0                  0           1
#           36704             0           0                  0           1
#           36705             0           0                  0           1
#           36706             0           0                  0           1
#
#                  crop_winter wheat
# CropStats 59                     0
#           60                     0
#           61                     0
#           62                     0
#           63                     0
# ...                            ...
#           36702                  0
#           36703                  0
#           36704                  0
#           36705                  0
#           36706                  0
#
# [34066 rows x 9 columns]

# %% [markdown]
# # 3 Set up

# %%
# initialize setup
classification_setup = setup(df, target='production (tonnes)', train_size=0.8, session_id=8)
# Out:
# <style type="text/css">
# #T_76250_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_76250" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76250_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_76250_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76250_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76250_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_76250_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76250_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_76250_row1_col1" class="data row1 col1" >production (tonnes)</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76250_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_76250_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76250_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_76250_row3_col1" class="data row3 col1" >(34066, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76250_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_76250_row4_col1" class="data row4 col1" >(34066, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76250_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_76250_row5_col1" class="data row5 col1" >(27252, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76250_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_76250_row6_col1" class="data row6 col1" >(6814, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76250_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_76250_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76250_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_76250_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76250_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_76250_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_76250_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_76250_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_76250_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_76250_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_76250_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_76250_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_76250_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_76250_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_76250_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_76250_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_76250_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_76250_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_76250_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_76250_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_76250_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_76250_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_76250_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_76250_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_76250_row18_col1" class="data row18 col1" >18aa</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 4 Comparing the models

# %%
# compare the performance of all estimators
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_fa920 th {
#   text-align: left;
# }
# #T_fa920_row0_col0, #T_fa920_row1_col0, #T_fa920_row1_col1, #T_fa920_row1_col2, #T_fa920_row1_col3, #T_fa920_row1_col4, #T_fa920_row1_col5, #T_fa920_row1_col6, #T_fa920_row2_col0, #T_fa920_row2_col1, #T_fa920_row2_col2, #T_fa920_row2_col3, #T_fa920_row2_col4, #T_fa920_row2_col5, #T_fa920_row2_col6, #T_fa920_row3_col0, #T_fa920_row3_col1, #T_fa920_row3_col2, #T_fa920_row3_col3, #T_fa920_row3_col4, #T_fa920_row3_col5, #T_fa920_row3_col6, #T_fa920_row4_col0, #T_fa920_row4_col1, #T_fa920_row4_col2, #T_fa920_row4_col3, #T_fa920_row4_col4, #T_fa920_row4_col5, #T_fa920_row4_col6, #T_fa920_row5_col0, #T_fa920_row5_col1, #T_fa920_row5_col2, #T_fa920_row5_col3, #T_fa920_row5_col4, #T_fa920_row5_col5, #T_fa920_row5_col6, #T_fa920_row6_col0, #T_fa920_row6_col1, #T_fa920_row6_col2, #T_fa920_row6_col3, #T_fa920_row6_col4, #T_fa920_row6_col5, #T_fa920_row6_col6, #T_fa920_row7_col0, #T_fa920_row7_col1, #T_fa920_row7_col2, #T_fa920_row7_col3, #T_fa920_row7_col4, #T_fa920_row7_col5, #T_fa920_row7_col6, #T_fa920_row8_col0, #T_fa920_row8_col1, #T_fa920_row8_col2, #T_fa920_row8_col3, #T_fa920_row8_col4, #T_fa920_row8_col5, #T_fa920_row8_col6, #T_fa920_row9_col0, #T_fa920_row9_col1, #T_fa920_row9_col2, #T_fa920_row9_col3, #T_fa920_row9_col4, #T_fa920_row9_col5, #T_fa920_row9_col6, #T_fa920_row10_col0, #T_fa920_row10_col1, #T_fa920_row10_col2, #T_fa920_row10_col3, #T_fa920_row10_col4, #T_fa920_row10_col5, #T_fa920_row10_col6, #T_fa920_row11_col0, #T_fa920_row11_col1, #T_fa920_row11_col2, #T_fa920_row11_col3, #T_fa920_row11_col4, #T_fa920_row11_col5, #T_fa920_row11_col6, #T_fa920_row12_col0, #T_fa920_row12_col1, #T_fa920_row12_col2, #T_fa920_row12_col3, #T_fa920_row12_col4, #T_fa920_row12_col5, #T_fa920_row12_col6, #T_fa920_row13_col0, #T_fa920_row13_col1, #T_fa920_row13_col2, #T_fa920_row13_col3, #T_fa920_row13_col4, #T_fa920_row13_col5, #T_fa920_row13_col6, #T_fa920_row14_col0, #T_fa920_row14_col1, #T_fa920_row14_col2, #T_fa920_row14_col3, #T_fa920_row14_col4, #T_fa920_row14_col5, #T_fa920_row14_col6, #T_fa920_row15_col0, #T_fa920_row15_col1, #T_fa920_row15_col2, #T_fa920_row15_col3, #T_fa920_row15_col4, #T_fa920_row15_col5, #T_fa920_row15_col6, #T_fa920_row16_col0, #T_fa920_row16_col1, #T_fa920_row16_col2, #T_fa920_row16_col3, #T_fa920_row16_col4, #T_fa920_row16_col5, #T_fa920_row16_col6, #T_fa920_row17_col0, #T_fa920_row17_col1, #T_fa920_row17_col2, #T_fa920_row17_col3, #T_fa920_row17_col4, #T_fa920_row17_col5, #T_fa920_row17_col6, #T_fa920_row18_col0, #T_fa920_row18_col1, #T_fa920_row18_col2, #T_fa920_row18_col3, #T_fa920_row18_col4, #T_fa920_row18_col5, #T_fa920_row18_col6 {
#   text-align: left;
# }
# #T_fa920_row0_col1, #T_fa920_row0_col2, #T_fa920_row0_col3, #T_fa920_row0_col4, #T_fa920_row0_col5, #T_fa920_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fa920_row0_col7, #T_fa920_row1_col7, #T_fa920_row2_col7, #T_fa920_row3_col7, #T_fa920_row4_col7, #T_fa920_row5_col7, #T_fa920_row6_col7, #T_fa920_row7_col7, #T_fa920_row8_col7, #T_fa920_row9_col7, #T_fa920_row10_col7, #T_fa920_row11_col7, #T_fa920_row12_col7, #T_fa920_row13_col7, #T_fa920_row14_col7, #T_fa920_row15_col7, #T_fa920_row16_col7, #T_fa920_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fa920_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fa920" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa920_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fa920_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fa920_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fa920_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fa920_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fa920_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fa920_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fa920_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa920_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_fa920_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_fa920_row0_col1" class="data row0 col1" >18206.3073</td>
#       <td id="T_fa920_row0_col2" class="data row0 col2" >35232430331.0440</td>
#       <td id="T_fa920_row0_col3" class="data row0 col3" >155074.7222</td>
#       <td id="T_fa920_row0_col4" class="data row0 col4" >0.9986</td>
#       <td id="T_fa920_row0_col5" class="data row0 col5" >0.0342</td>
#       <td id="T_fa920_row0_col6" class="data row0 col6" >0.0093</td>
#       <td id="T_fa920_row0_col7" class="data row0 col7" >5.2350</td>
#     </tr>
#     <tr>
#       <th id="T_fa920_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_fa920_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_fa920_row1_col1" class="data row1 col1" >29905.8844</td>
#       <td id="T_fa920_row1_col2" class="data row1 col2" >62068097735.4593</td>
#       <td id="T_fa920_row1_col3" class="data row1 col3" >234362.6934</td>
#       <td id="T_fa920_row1_col4" class="data row1 col4" >0.9976</td>
#       <td id="T_fa920_row1_col5" class="data row1 col5" >0.0391</td>
#       <td id="T_fa920_row1_col6" class="data row1 col6" >0.0136</td>
#       <td id="T_fa920_row1_col7" class="data row1 col7" >8.6640</td>
#     </tr>
#     <tr>
#       <th id="T_fa920_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_fa920_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#       <td id="T_fa920_row2_col1" class="data row2 col1" >64366.2930</td>
#       <td id="T_fa920_row2_col2" class="data row2 col2" >153501555793.8739</td>
#       <td id="T_fa920_row2_col3" class="data row2 col3" >385381.7951</td>
#       <td id="T_fa920_row2_col4" class="data row2 col4" >0.9938</td>
#       <td id="T_fa920_row2_col5" class="data row2 col5" >0.0585</td>
#       <td id="T_fa920_row2_col6" class="data row2 col6" >0.0308</td>
#       <td id="T_fa920_row2_col7" class="data row2 col7" >0.2390</td>
#     </tr>
#     <tr>
#       <th id="T_fa920_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_fa920_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_fa920_row3_col1" class="data row3 col1" >146139.6985</td>
#       <td id="T_fa920_row3_col2" class="data row3 col2" >151013546093.5138</td>
#       <td id="T_fa920_row3_col3" class="data row3 col3" >384667.9262</td>
#       <td id="T_fa920_row3_col4" class="data row3 col4" >0.9938</td>
#       <td id="T_fa920_row3_col5" class="data row3 col5" >1.2116</td>
#       <td id="T_fa920_row3_col6" class="data row3 col6" >13.2273</td>
#       <td id="T_fa920_row3_col7" class="data row3 col7" >2.3720</td>
#     </tr>
#     <tr>
#       <th id="T_fa920_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_fa920_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_fa920_row4_col1" class="data row4 col1" >77796.7715</td>
#       <td id="T_fa920_row4_col2" class="data row4 col2" >391438956953.6000</td>
#       <td id="T_fa920_row4_col3" class="data row4 col3" >595193.2594</td>
#       <td id="T_fa920_row4_col4" class="data row4 col4" >0.9846</td>
#       <td id="T_fa920_row4_col5" class="data row4 col5" >0.4641</td>
#       <td id="T_fa920_row4_col6" class="data row4 col6" >0.7256</td>
#       <td id="T_fa920_row4_col7" class="data row4 col7" >0.3860</td>
#     </tr>
#     <tr>
#       <th id="T_fa920_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_fa920_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_fa920_row5_col1" class="data row5 col1" >87061.5321</td>
#       <td id="T_fa920_row5_col2" class="data row5 col2" >452091647248.8073</td>
#       <td id="T_fa920_row5_col3" class="data row5 col3" >654986.4682</td>
#       <t
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %% [markdown]
# # 5 Creating a model from our best estimator

# %%
# create model
model = create_model(best_model)
# Out:
# <style type="text/css">
# #T_6da0a_row10_col0, #T_6da0a_row10_col1, #T_6da0a_row10_col2, #T_6da0a_row10_col3, #T_6da0a_row10_col4, #T_6da0a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6da0a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6da0a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6da0a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6da0a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6da0a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6da0a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6da0a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6da0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6da0a_row0_col0" class="data row0 col0" >14694.9338</td>
#       <td id="T_6da0a_row0_col1" class="data row0 col1" >9798643352.0596</td>
#       <td id="T_6da0a_row0_col2" class="data row0 col2" >98988.0970</td>
#       <td id="T_6da0a_row0_col3" class="data row0 col3" >0.9996</td>
#       <td id="T_6da0a_row0_col4" class="data row0 col4" >0.0496</td>
#       <td id="T_6da0a_row0_col5" class="data row0 col5" >0.0111</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6da0a_row1_col0" class="data row1 col0" >17898.7978</td>
#       <td id="T_6da0a_row1_col1" class="data row1 col1" >19096545783.2281</td>
#       <td id="T_6da0a_row1_col2" class="data row1 col2" >138190.2521</td>
#       <td id="T_6da0a_row1_col3" class="data row1 col3" >0.9992</td>
#       <td id="T_6da0a_row1_col4" class="data row1 col4" >0.0336</td>
#       <td id="T_6da0a_row1_col5" class="data row1 col5" >0.0101</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6da0a_row2_col0" class="data row2 col0" >13785.8007</td>
#       <td id="T_6da0a_row2_col1" class="data row2 col1" >6035728825.8778</td>
#       <td id="T_6da0a_row2_col2" class="data row2 col2" >77689.9532</td>
#       <td id="T_6da0a_row2_col3" class="data row2 col3" >0.9997</td>
#       <td id="T_6da0a_row2_col4" class="data row2 col4" >0.0274</td>
#       <td id="T_6da0a_row2_col5" class="data row2 col5" >0.0085</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6da0a_row3_col0" class="data row3 col0" >26382.3532</td>
#       <td id="T_6da0a_row3_col1" class="data row3 col1" >208903436908.9523</td>
#       <td id="T_6da0a_row3_col2" class="data row3 col2" >457059.5551</td>
#       <td id="T_6da0a_row3_col3" class="data row3 col3" >0.9917</td>
#       <td id="T_6da0a_row3_col4" class="data row3 col4" >0.0425</td>
#       <td id="T_6da0a_row3_col5" class="data row3 col5" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6da0a_row4_col0" class="data row4 col0" >20887.6582</td>
#       <td id="T_6da0a_row4_col1" class="data row4 col1" >37126734288.4177</td>
#       <td id="T_6da0a_row4_col2" class="data row4 col2" >192682.9891</td>
#       <td id="T_6da0a_row4_col3" class="data row4 col3" >0.9989</td>
#       <td id="T_6da0a_row4_col4" class="data row4 col4" >0.0165</td>
#       <td id="T_6da0a_row4_col5" class="data row4 col5" >0.0072</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6da0a_row5_col0" class="data row5 col0" >15446.5024</td>
#       <td id="T_6da0a_row5_col1" class="data row5 col1" >10915701277.6967</td>
#       <td id="T_6da0a_row5_col2" class="data row5 col2" >104478.2335</td>
#       <td id="T_6da0a_row5_col3" class="data row5 col3" >0.9994</td>
#       <td id="T_6da0a_row5_col4" class="data row5 col4" >0.0364</td>
#       <td id="T_6da0a_row5_col5" class="data row5 col5" >0.0104</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6da0a_row6_col0" class="data row6 col0" >20227.8427</td>
#       <td id="T_6da0a_row6_col1" class="data row6 col1" >17809603290.1464</td>
#       <td id="T_6da0a_row6_col2" class="data row6 col2" >133452.6256</td>
#       <td id="T_6da0a_row6_col3" class="data row6 col3" >0.9994</td>
#       <td id="T_6da0a_row6_col4" class="data row6 col4" >0.0384</td>
#       <td id="T_6da0a_row6_col5" class="data row6 col5" >0.0099</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6da0a_row7_col0" class="data row7 col0" >18419.1901</td>
#       <td id="T_6da0a_row7_col1" class="data row7 col1" >17145007802.2772</td>
#       <td id="T_6da0a_row7_col2" class="data row7 col2" >130938.9469</td>
#       <td id="T_6da0a_row7_col3" class="data row7 col3" >0.9992</td>
#       <td id="T_6da0a_row7_col4" class="data row7 col4" >0.0410</td>
#       <td id="T_6da0a_row7_col5" class="data row7 col5" >0.0081</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6da0a_row8_col0" class="data row8 col0" >18991.7482</td>
#       <td id="T_6da0a_row8_col1" class="data row8 col1" >19426330401.5281</td>
#       <td id="T_6da0a_row8_col2" class="data row8 col2" >139378.3714</td>
#       <td id="T_6da0a_row8_col3" class="data row8 col3" >0.9992</td>
#       <td id="T_6da0a_row8_col4" class="data row8 col4" >0.0348</td>
#       <td id="T_6da0a_row8_col5" class="data row8 col5" >0.0095</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6da0a_row9_col0" class="data row9 col0" >15328.2456</td>
#       <td id="T_6da0a_row9_col1" class="data row9 col1" >6066571380.2564</td>
#       <td id="T_6da0a_row9_col2" class="data row9 col2" >77888.1980</td>
#       <td id="T_6da0a_row9_col3" class="data row9 col3" >0.9998</td>
#       <td id="T_6da0a_row9_col4" class="data row9 col4" >0.0215</td>
#       <td id="T_6da0a_row9_col5" class="data row9 col5" >0.0081</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6da0a_row10_col0" class="data row10 col0" >18206.3073</td>
#       <td id="T_6da0a_row10_col1" class="data row10 col1" >35232430331.0440</td>
#       <td id="T_6da0a_row10_col2" class="data row10 col2" >155074.7222</td>
#       <td id="T_6da0a_row10_col3" class="data row10 col3" >0.9986</td>
#       <td id="T_6da0a_row10_col4" class="data row10 col4" >0.0342</td>
#       <td id="T_6da0a_row10_col5" class="data row10 col5" >0.0093</td>
#     </tr>
#     <tr>
#       <th id="T_6da0a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6da0a_row11_col0" class="data row11 col0" >3558.8082</td>
#       <td id="T_6da0a_row11_col1" class="data row11 col1" >58521271152.7061</td>
#       <td id="T_6da0a_row11_col2" class="data row11 col2" >105755.6659</td>
#       <td id="T_6da0a_row11_col3" class="data row11 col3" >0.0023</td>
#       <td id="T_6da0a_row11_col4" class="data row11 col4" >0.0095</td>
#       <td id="T_6da0a_row11_col5" class="data row11 col5" >0.0012</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# # 6 Predicting on the model

# %%
# predict on test set
predictions = predict_model(model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d1b86" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1b86_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d1b86_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d1b86_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d1b86_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d1b86_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d1b86_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d1b86_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1b86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1b86_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_d1b86_row0_col1" class="data row0 col1" >16122.5151</td>
#       <td id="T_d1b86_row0_col2" class="data row0 col2" >11097753651.1076</td>
#       <td id="T_d1b86_row0_col3" class="data row0 col3" >105345.8763</td>
#       <td id="T_d1b86_row0_col4" class="data row0 col4" >0.9996</td>
#       <td id="T_d1b86_row0_col5" class="data row0 col5" >0.0340</td>
#       <td id="T_d1b86_row0_col6" class="data row0 col6" >0.0090</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 7 Plotting the results of the best model

# %% [markdown]
# ## Plotting the error

# %%
# plot the regression results on a scatter plot
plot_model(model, plot = 'error')

# %% [markdown]
# ## Manifold plot
# This plot shows the dimensionality of the data.

# %%
# plot the regression results on a scatter plot
plot_model(model, plot = 'manifold')

# %%
plot_model(model, plot = 'vc')
